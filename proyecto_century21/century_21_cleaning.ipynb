# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv('src/century_scrape_sebastian.csv')
df.head()
# Out:
#                                              precios mantenimiento  \
# 0  {'vista': {'precio': 11500.000000000002, 'mone...           NaN
# 1  {'vista': {'precio': 7500, 'moneda': 'MXN', 'p...           NaN
# 2  {'vista': {'precio': 6300, 'moneda': 'MXN', 'p...           NaN
# 3  {'vista': {'precio': 11000, 'moneda': 'MXN', '...           NaN
# 4  {'vista': {'precio': 5000, 'moneda': 'MXN', 'p...           NaN
#
#   precioFormat precioMapa precioSecundarioFormat monedaSecundaria  \
# 0  $11,500 MXN     11,500            $11,500 MXN              MXN
# 1   $7,500 MXN      7,500             $7,500 MXN              MXN
# 2   $6,300 MXN      6,300             $6,300 MXN              MXN
# 3  $11,000 MXN     11,000            $11,000 MXN              MXN
# 4   $5,000 MXN      5,000             $5,000 MXN              MXN
#
#    mostrarMonedaSecundaria tipoOperacionTxt tipoPropiedadEnTipoOperacion  \
# 0                    False         en renta                Casa en renta
# 1                    False         en renta  Casa en condominio en renta
# 2                    False         en renta               Local en renta
# 3                    False         en renta                Casa en renta
# 4                    False         en renta                Casa en renta
#
#   diasModificacionTxt  ... idAsesor          telefono        whatsapp  \
# 0                 Hoy  ...     3899  +52 55 3239 2705 525532392705.00
# 1                 Hoy  ...    15680  +52 442 359 9277 524423599277.00
# 2                 Hoy  ...    30026  +52 771 454 0334             NaN
# 3                 Hoy  ...    21788  +52 646 113 9696 526461139696.00
# 4                 Hoy  ...    20677  +52 722 868 9076             NaN
#
#                          email                    asesorNombre  \
# 0      anel@century21doniz.com       Maria Anel Esqueda Segura
# 1    mtrujillo141089@gmail.com           Paola Trujillo Toledo
# 2     contacto@c21novareal.com            CENTURY 21 Nova Real
# 3          info.c21f@gmail.com      Lic. Sonia Escobedo Medina
# 4  contacto@c21houseempire.com  Erick Gabriel Chavez Hernandez
#
#                                      asesorThumbnail  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#    asesorFotoMostrarEnInternet  \
# 0                         True
# 1                         True
# 2                        False
# 3                         True
# 4                        False
#
#                                          logoOficina  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#                  nombreAfiliado  \
# 0  CENTURY 21 Doniz & Asociados
# 1           CENTURY 21 Trums-AG
# 2          CENTURY 21 Nova Real
# 3          CENTURY 21 Fortaleza
# 4       CENTURY 21 House Empire
#
#                                                fotos
# 0  {'totalFotos': 16, 'propiedadThumbnail': ['htt...
# 1  {'totalFotos': 32, 'propiedadThumbnail': ['htt...
# 2  {'totalFotos': 8, 'propiedadThumbnail': ['http...
# 3  {'totalFotos': 12, 'propiedadThumbnail': ['htt...
# 4  {'totalFotos': 21, 'propiedadThumbnail': ['htt...
#
# [5 rows x 91 columns]

# %%
df['m2TTxt'].value_counts()
# Out:
# m2TTxt
# m² Terreno                22838
# Hectáreas Terreno           161
# Pies Cuadrados Terreno       11
# Acres Terreno                 1
# Name: count, dtype: int64

# %%
filtro = (df['m2TTxt']=='Hectáreas Terreno') & (df['m2CSort']>0) 
df[filtro][['tipoPropiedadTrans', 'm2TTxt', 'm2T', 'm2TSort', 'm2C', 'm2CSort']].sort_values(by='m2CSort', ascending=False)
# Out:
#         tipoPropiedadTrans             m2TTxt     m2T     m2TSort     m2C  \
# 21777              terreno  Hectáreas Terreno 1863.00 18630000.00 1863.00
# 21778              terreno  Hectáreas Terreno 1378.00 13780000.00 1378.00
# 22285              terreno  Hectáreas Terreno  290.00  2900000.00  650.00
# 19503              terreno  Hectáreas Terreno   14.80   148020.00  350.00
# 10822               quinta  Hectáreas Terreno    0.27     2684.00  325.00
# 20767             hacienda  Hectáreas Terreno    3.00    30000.00  313.00
# 21759              terreno  Hectáreas Terreno  250.00  2500000.00  250.00
# 21782              terreno  Hectáreas Terreno  235.00  2350000.00  235.00
# 17810              terreno  Hectáreas Terreno   16.00   160000.00  150.00
# 20691              terreno  Hectáreas Terreno    3.70    37000.00  100.00
# 20789               rancho  Hectáreas Terreno   93.00   930000.00   54.00
# 10975               rancho  Hectáreas Terreno   24.00   240000.00   24.00
# 16240  inmueble productivo  Hectáreas Terreno   22.50   225000.00   22.50
# 20745              terreno  Hectáreas Terreno  144.00  1440000.00    1.00
# 20924               rancho  Hectáreas Terreno  272.00  2720000.00    1.00
#
#           m2CSort
# 21777 18630000.00
# 21778 13780000.00
# 22285  6500000.00
# 19503  3500000.00
# 10822  3250000.00
# 20767  3130000.00
# 21759  2500000.00
# 21782  2350000.00
# 17810  1500000.00
# 20691  1000000.00
# 20789   540000.00
# 10975   240000.00
# 16240   225000.00
# 20745    10000.00
# 20924    10000.00

# %% [markdown]
# Se revisan las filas que poseen la medida de terrno en Hectáreas, se eliminan las filas sin info concluyente y se reemplaza los valores donde las hectáreas eran metros cuadrados

# %%
df.drop(index=[22285,10822,20924,20745,21778,21759,21782],inplace=True)
df.loc[[17810, 20691, 20767, 20789], 'm2CSort'] = df.loc[[17810, 20691, 20767, 20789], 'm2C']
df.loc[[19503,10975,16240,21777], 'm2CSort'] = [450, 35.27, 0,0]

# %% [markdown]
# La información para pies cuadrados calza correctamente

# %%
filtro = (df['m2TTxt']=='Pies Cuadrados Terreno') & (df['m2CSort']>0) 
df[filtro][['tipoPropiedadTrans', 'm2TTxt', 'm2T', 'm2TSort', 'm2C', 'm2CSort']].sort_values(by='m2CSort', ascending=False)
# Out:
#       tipoPropiedadTrans                  m2TTxt        m2T  m2TSort  \
# 3454                nave  Pies Cuadrados Terreno 1067400.00 99164.66
# 3206                nave  Pies Cuadrados Terreno  410000.00 38090.23
# 3512                nave  Pies Cuadrados Terreno   79578.84  7393.11
# 3200                nave  Pies Cuadrados Terreno   11844.00  1100.34
# 3464                nave  Pies Cuadrados Terreno   41831.90  3886.31
# 3746                nave  Pies Cuadrados Terreno   47695.00  4431.01
# 3461                nave  Pies Cuadrados Terreno   21771.49  2022.64
# 19911       departamento  Pies Cuadrados Terreno    1517.27   140.96
# 19762       departamento  Pies Cuadrados Terreno    1517.27   140.96
# 12143       departamento  Pies Cuadrados Terreno     592.01    55.00
# 12631       departamento  Pies Cuadrados Terreno      80.00     7.43
#
#             m2C  m2CSort
# 3454  530515.90 49286.52
# 3206  180082.00 16730.16
# 3512  133373.23 12390.77
# 3200   65388.50  6074.79
# 3464   41831.90  3886.31
# 3746   21800.00  2025.29
# 3461   21771.49  2022.64
# 19911   1517.27   140.96
# 19762   1517.27   140.96
# 12143    592.01    55.00
# 12631     80.00     7.43

# %% [markdown]
# Se transforma el campo de precio a uno válido

# %%
df['precioSecundarioFormat'] = df['precioSecundarioFormat'].str.replace('$', '', regex=False)\
                                                           .str.replace(',', '', regex=False)\
                                                           .str.replace(' MXN', '', regex=False)
df['precioSecundarioFormat'] = df['precioSecundarioFormat'].astype(float)
df.head()
# Out:
#                                              precios mantenimiento  \
# 0  {'vista': {'precio': 11500.000000000002, 'mone...           NaN
# 1  {'vista': {'precio': 7500, 'moneda': 'MXN', 'p...           NaN
# 2  {'vista': {'precio': 6300, 'moneda': 'MXN', 'p...           NaN
# 3  {'vista': {'precio': 11000, 'moneda': 'MXN', '...           NaN
# 4  {'vista': {'precio': 5000, 'moneda': 'MXN', 'p...           NaN
#
#   precioFormat precioMapa  precioSecundarioFormat monedaSecundaria  \
# 0  $11,500 MXN     11,500                11500.00              MXN
# 1   $7,500 MXN      7,500                 7500.00              MXN
# 2   $6,300 MXN      6,300                 6300.00              MXN
# 3  $11,000 MXN     11,000                11000.00              MXN
# 4   $5,000 MXN      5,000                 5000.00              MXN
#
#    mostrarMonedaSecundaria tipoOperacionTxt tipoPropiedadEnTipoOperacion  \
# 0                    False         en renta                Casa en renta
# 1                    False         en renta  Casa en condominio en renta
# 2                    False         en renta               Local en renta
# 3                    False         en renta                Casa en renta
# 4                    False         en renta                Casa en renta
#
#   diasModificacionTxt  ... idAsesor          telefono        whatsapp  \
# 0                 Hoy  ...     3899  +52 55 3239 2705 525532392705.00
# 1                 Hoy  ...    15680  +52 442 359 9277 524423599277.00
# 2                 Hoy  ...    30026  +52 771 454 0334             NaN
# 3                 Hoy  ...    21788  +52 646 113 9696 526461139696.00
# 4                 Hoy  ...    20677  +52 722 868 9076             NaN
#
#                          email                    asesorNombre  \
# 0      anel@century21doniz.com       Maria Anel Esqueda Segura
# 1    mtrujillo141089@gmail.com           Paola Trujillo Toledo
# 2     contacto@c21novareal.com            CENTURY 21 Nova Real
# 3          info.c21f@gmail.com      Lic. Sonia Escobedo Medina
# 4  contacto@c21houseempire.com  Erick Gabriel Chavez Hernandez
#
#                                      asesorThumbnail  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#    asesorFotoMostrarEnInternet  \
# 0                         True
# 1                         True
# 2                        False
# 3                         True
# 4                        False
#
#                                          logoOficina  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#                  nombreAfiliado  \
# 0  CENTURY 21 Doniz & Asociados
# 1           CENTURY 21 Trums-AG
# 2          CENTURY 21 Nova Real
# 3          CENTURY 21 Fortaleza
# 4       CENTURY 21 House Empire
#
#                                                fotos
# 0  {'totalFotos': 16, 'propiedadThumbnail': ['htt...
# 1  {'totalFotos': 32, 'propiedadThumbnail': ['htt...
# 2  {'totalFotos': 8, 'propiedadThumbnail': ['http...
# 3  {'totalFotos': 12, 'propiedadThumbnail': ['htt...
# 4  {'totalFotos': 21, 'propiedadThumbnail': ['htt...
#
# [5 rows x 91 columns]

# %% [markdown]
# Se limpia la columna de cuota mantenimiento, dejando solo los valores numericos

# %%
df['cuotaMantenimiento_limpia'] = df['cuotaMantenimiento'].str.extract('(\d+)', expand=False)
df['cuotaMantenimiento_limpia'] = pd.to_numeric(df['cuotaMantenimiento_limpia'], errors='coerce') # si existe algun valor incorrecto lo dejará como nulo
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_11144\1433485608.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['cuotaMantenimiento_limpia'] = df['cuotaMantenimiento'].str.extract('(\d+)', expand=False)

# %% [markdown]
# Se rellena con 0 todos los valores nulos

# %%
df['cuotaMantenimiento_limpia'] = df['cuotaMantenimiento_limpia'].fillna(0)

# %% [markdown]
# Se suma el precio con la cuota de mantenimiento

# %%
df['precio_con_mantenimiento'] = df['precioSecundarioFormat'] + df['cuotaMantenimiento_limpia']
df.head()
# Out:
#                                              precios mantenimiento  \
# 0  {'vista': {'precio': 11500.000000000002, 'mone...           NaN
# 1  {'vista': {'precio': 7500, 'moneda': 'MXN', 'p...           NaN
# 2  {'vista': {'precio': 6300, 'moneda': 'MXN', 'p...           NaN
# 3  {'vista': {'precio': 11000, 'moneda': 'MXN', '...           NaN
# 4  {'vista': {'precio': 5000, 'moneda': 'MXN', 'p...           NaN
#
#   precioFormat precioMapa  precioSecundarioFormat monedaSecundaria  \
# 0  $11,500 MXN     11,500                11500.00              MXN
# 1   $7,500 MXN      7,500                 7500.00              MXN
# 2   $6,300 MXN      6,300                 6300.00              MXN
# 3  $11,000 MXN     11,000                11000.00              MXN
# 4   $5,000 MXN      5,000                 5000.00              MXN
#
#    mostrarMonedaSecundaria tipoOperacionTxt tipoPropiedadEnTipoOperacion  \
# 0                    False         en renta                Casa en renta
# 1                    False         en renta  Casa en condominio en renta
# 2                    False         en renta               Local en renta
# 3                    False         en renta                Casa en renta
# 4                    False         en renta                Casa en renta
#
#   diasModificacionTxt  ...        whatsapp                        email  \
# 0                 Hoy  ... 525532392705.00      anel@century21doniz.com
# 1                 Hoy  ... 524423599277.00    mtrujillo141089@gmail.com
# 2                 Hoy  ...             NaN     contacto@c21novareal.com
# 3                 Hoy  ... 526461139696.00          info.c21f@gmail.com
# 4                 Hoy  ...             NaN  contacto@c21houseempire.com
#
#                      asesorNombre  \
# 0       Maria Anel Esqueda Segura
# 1           Paola Trujillo Toledo
# 2            CENTURY 21 Nova Real
# 3      Lic. Sonia Escobedo Medina
# 4  Erick Gabriel Chavez Hernandez
#
#                                      asesorThumbnail  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#    asesorFotoMostrarEnInternet  \
# 0                         True
# 1                         True
# 2                        False
# 3                         True
# 4                        False
#
#                                          logoOficina  \
# 0  https://cdn.21online.lat/mexico/cache/awsTest1...
# 1  https://cdn.21online.lat/mexico/cache/awsTest1...
# 2  https://cdn.21online.lat/mexico/cache/awsTest1...
# 3  https://cdn.21online.lat/mexico/cache/awsTest1...
# 4  https://cdn.21online.lat/mexico/cache/awsTest1...
#
#                  nombreAfiliado  \
# 0  CENTURY 21 Doniz & Asociados
# 1           CENTURY 21 Trums-AG
# 2          CENTURY 21 Nova Real
# 3          CENTURY 21 Fortaleza
# 4       CENTURY 21 House Empire
#
#                                                fotos  \
# 0  {'totalFotos': 16, 'propiedadThumbnail': ['htt...
# 1  {'totalFotos': 32, 'propiedadThumbnail': ['htt...
# 2  {'totalFotos': 8, 'propiedadThumbnail': ['http...
# 3  {'totalFotos': 12, 'propiedadThumbnail': ['htt...
# 4  {'totalFotos': 21, 'propiedadThumbnail': ['htt...
#
#    cuotaMantenimiento_limpia  precio_con_mantenimiento
# 0                       0.00                  11500.00
# 1                       0.00                   7500.00
# 2                       0.00                   6300.00
# 3                       0.00                  11000.00
# 4                       0.00                   5000.00
#
# [5 rows x 93 columns]

# %% [markdown]
# Se eliminan las columnas que no se necesitan

# %%
df.drop(columns=['diasModificacionTxt','diasModificacionTxt','fotos', 'logoOficina', 'asesorFotoMostrarEnInternet', 'mostrarMonedaSecundaria','monedaSecundaria','precios', 'whatsapp',
                 'metaTags', 'etiquetas', 'asesorThumbnail','idAsesor', 'idAfiliados', 'idOriginal', 'id',
                 'idPropiedadesOS','idPropiedadesDB', 'idAfiliadosOS', 'fotos360', 'conVideo', 'conMapa', 'status', 'statusTrans', 'enInternet',
                 'idAfiliadosDB','idAsesoresOS', 'idAsesoresDB', 'mascotasTxtShort', 'albercaTxt', 'albercaTxtShort', 'recorridoVirtual',
                 'idAsesoresOriginalOS','idAsesoresOriginalDB', 'fechaAlta', 'banosTxtShort', 'estacionamientosTxt', 'estacionamientosTxtShort', 'mascotasTxt',
                 'fechaModificacion', 'ocultarCalleInternet', 'recamarasTxt', 'recamarasTxtShort', 'banosTxt',
                 'ocultarNumeroInternet', 'coloniaWeb', 'unidadDeMedida','municipioWeb', 'm2CTxt', 'estadoWeb', 'paisWeb',
                 'tipoOperacionTxt', 'precioMapa','tipoOperacionTrans', 'precio', 'moneda', 'ocultarPrecioInternet', 'pais', 'calle',
                 'tipoPropiedadEnTipoOperacion', 'tipoPropiedad','m2CFormat', 'm2TTxt', 'm2TFormat','m2T', 'm2C', 'precioFormat', 'telefono', 'email', 'asesorNombre', 'nombreAfiliado'
                 ], axis=1, inplace=True)
df.head()
# Out:
#   mantenimiento  precioSecundarioFormat  \
# 0           NaN                11500.00
# 1           NaN                 7500.00
# 2           NaN                 6300.00
# 3           NaN                11000.00
# 4           NaN                 5000.00
#
#                                 urlCorrectaPropiedad  \
# 0  /propiedad/525486_casa-en-condominio-horizonta...
# 1  /propiedad/554784_casa-en-renta-en-colinas-de-...
# 2  /propiedad/554827_local-en-renta-en-paseos-de-...
# 3  /propiedad/554808_casa-en-renta-1-planta-de-2-...
# 4  /propiedad/554850_casa-en-renta-en-rinconada-d...
#
#                          colonia              municipio            estado  \
# 0                   El Contadero  Cuajimalpa De Morelos  Ciudad De México
# 1           Colinas de la Piedad             El Marqués         Querétaro
# 2            Paseos de Chavarría  Mineral De La Reforma           Hidalgo
# 3                Villa Fontana I                Tijuana   Baja California
# 4  San José Buenavista El Grande                Temoaya  Estado De México
#
#     lat     lon tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort  \
# 0 19.35  -99.30         renta                NaN  ...    95.00   90.00
# 1 20.59 -100.26         renta                NaN  ...   127.42   62.72
# 2 20.04  -98.71         renta                NaN  ...    79.00   79.00
# 3 32.51 -116.87         renta                NaN  ...    80.00   65.00
# 4 19.41  -99.58         renta                NaN  ...    60.00   60.00
#
#   recamaras  banos  estacionamientos  mascotas  alberca  exclusiva  \
# 0      3.00   1.00              1.00     False      NaN       True
# 1      2.00   1.00              1.00     False      NaN       True
# 2       NaN   1.00              3.00     False      NaN       True
# 3      2.00   1.00              1.00     False      NaN       True
# 4      3.00   2.00              1.00     False      NaN       True
#
#    cuotaMantenimiento_limpia precio_con_mantenimiento
# 0                       0.00                 11500.00
# 1                       0.00                  7500.00
# 2                       0.00                  6300.00
# 3                       0.00                 11000.00
# 4                       0.00                  5000.00
#
# [5 rows x 23 columns]

# %% [markdown]
# Se separan los df de casa, departamento y terreno para trabajar por separado en cada uno de ellos

# %%
df_casa = df[df['tipoPropiedadTrans']=='casa'].reset_index(drop=True)
df_dpto = df[df['tipoPropiedadTrans']=='departamento'].reset_index(drop=True)
df_terreno = df[df['tipoPropiedadTrans']=='terreno'].reset_index(drop=True)

# %%
len(df_casa)
# Out:
# 6709

# %%
df_casa.groupby(['tipoOperacion'])['precioSecundarioFormat'].describe()
# Out:
#                 count       mean        std      min        25%        50%  \
# tipoOperacion
# renta          812.00   24551.75   24216.35  1700.00   12000.00   18000.00
# venta         5879.00 6637370.28 9215501.15 15000.00 2400000.00 4010000.00
#
#                      75%          max
# tipoOperacion
# renta           28000.00    400000.00
# venta         7200000.00 201233146.00

# %%
total_casa = len(df_casa)
nulos_casa = df_casa['precioSecundarioFormat'].isna().sum()
prtje_nulos_casa = (nulos_casa/total_casa)*100

print(f'El porcentaje de casa con precios nulos es {prtje_nulos_casa:.2f}%')
# Out:
# El porcentaje de casa con precios nulos es 0.27%

# %% [markdown]
# Se eliminan las casas con valores nulos

# %%
df_casa.dropna(subset=['precioSecundarioFormat'], inplace=True)

# %% [markdown]
# Se elimina la casa con el valor minimo ya que el arriendo de ella era por noche

# %%
df_casa.drop(index=[168], inplace=True) 
df_casa.reset_index(drop=True, inplace=True)

# %% [markdown]
# Se revisan las propiedades que poseen, ambos, recamaras y baños como nulos y ademas tienen menos de 20m2 de construcción

# %%
df_casa.query("banos.isnull() and recamaras.isnull() and m2CSort<20")
# Out:
#      mantenimiento  precioSecundarioFormat  \
# 465            NaN                15000.00
# 836            NaN               463840.00
# 1129           NaN              1026270.00
# 1455           NaN              1250000.00
# 1907           NaN              1800000.00
# 2303           NaN              2225000.00
# 2451           NaN              3050000.00
# 2562           NaN              2500000.00
# 2810           NaN              2800000.00
# 3479           NaN              3640018.00
# 3854           NaN              3950000.00
# 4367           NaN              5000000.00
# 5379           NaN              7500000.00
# 5764           NaN             10000000.00
# 5872           NaN             11327723.00
# 6311           NaN             18000000.00
#
#                                    urlCorrectaPropiedad  \
# 465        /propiedad/529155_casa-en-renta-en-chihuahua
# 836   /propiedad/502943_preventa-lotes-residenciales...
# 1129  /propiedad/552870_construya-su-casa-de-ensueno...
# 1455  /propiedad/284086_se-vende-terreno-en-col-beni...
# 1907  /propiedad/278473_venta-de-casa-como-terreno-e...
# 2303  /propiedad/502634_terreno-en-venta-en-francisc...
# 2451  /propiedad/502923_terreno-venta-tequila-jalapa...
# 2562  /propiedad/514901_casa-en-venta-en-10-de-abril...
# 2810           /propiedad/445808_preventa-de-casa-nueva
# 3479  /propiedad/536295_terreno-en-venta-carretera-n...
# 3854  /propiedad/540317_casa-en-venta-en-fraccionami...
# 4367  /propiedad/501165_casa-en-venta-barrio-cuarto-...
# 5379  /propiedad/523054_casas-en-venta-fraccionamien...
# 5764  /propiedad/527642_casa-en-venta-tequesquitengo...
# 5872  /propiedad/472017_terrenos-en-aldea-zama-tulum...
# 6311                   /propiedad/554358_racho-en-venta
#
#                                    colonia       municipio            estado  \
# 465                    Paseos De Chihuahua       Chihuahua         Chihuahua
# 836                              Esperanza           Colon         Querétaro
# 1129                               Kikteil          Mérida           Yucatán
# 1455                   Benito Juárez Norte   Coatzacoalcos          Veracruz
# 1907  Esfuerzo De Los Hermanos Del Trabajo   Coatzacoalcos          Veracruz
# 2303                    San Francisco Magú  Nicolás Romero  Estado De México
# 2451                               Tequila          Jalapa           Tabasco
# 2562                           10 de Abril         Temixco           Morelos
# 2810                    Lomas De Barrillas   Coatzacoalcos          Veracruz
# 3479                        El Uro Oriente       Monterrey        Nuevo León
# 3854                            El Becerro          Celaya        Guanajuato
# 4367                                 Oluta           Oluta          Veracruz
# 5379                                 Tulum           Tulum      Quintana Roo
# 5764                        Tequesquitengo  Tequesquitengo           Morelos
# 5872                            Aldea Zama           Tulum      Quintana Roo
# 6311                               Abasolo         Abasolo        Guanajuato
#
#        lat     lon tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort  \
# 465  28.72 -106.14         renta                NaN  ...     0.00    0.00
# 836  20.64 -100.11         venta                NaN  ...   160.00    0.00
# 1129 21.12  -89.70         venta                NaN  ...     0.00    0.00
# 1455 18.13  -94.45         venta                NaN  ...   321.00    0.00
# 1907 18.14  -94.42         venta                NaN  ...   415.00    0.00
# 2303 19.69  -99.35         venta                NaN  ... 14834.00    0.00
# 2451 17.88  -92.70         venta                NaN  ...  7572.00    0.00
# 2562 18.86  -99.23         venta                NaN  ...   301.00    0.00
# 2810 18.15  -94.54         venta                NaN  ...   176.00    0.00
# 3479 25.53 -100.21         venta                NaN  ...   577.00    0.00
# 3854 20.46 -100.80         venta                NaN  ...     0.00    0.00
# 4367 17.94  -94.90         venta                NaN  ...  1377.00    0.00
# 5379 20.22  -87.47         venta                NaN  ...     0.00    0.00
# 5764 18.62  -99.27         venta                NaN  ...   832.30    0.00
# 5872 20.20  -87.45         venta                NaN  ...  1387.00    0.00
# 6311 20.45 -101.53         venta                NaN  ... 22500.00    2.33
#
#      recamaras  banos  estacionamientos  mascotas  alberca  exclusiva  \
# 465        NaN    NaN               NaN     False      NaN       True
# 836        NaN    NaN               NaN     False      NaN       True
# 1129       NaN    NaN               NaN      True     True       True
# 1455       NaN    NaN               NaN      True      NaN       True
# 1907       NaN    NaN               NaN      True      NaN       True
# 2303       NaN    NaN               NaN     False      NaN       True
# 2451       NaN    NaN               NaN      True      NaN       True
# 2562       NaN    NaN               NaN     False      NaN       True
# 2810       NaN    NaN               NaN     False     True       True
# 3479       NaN    NaN               NaN      True     True      False
# 3854       NaN    NaN               NaN     False      NaN      False
# 4367       NaN    NaN               NaN     False      NaN       True
# 5379       NaN    NaN               NaN      True     True      False
# 5764       NaN    NaN               NaN     False      NaN      False
# 5872       NaN    NaN               NaN     False      NaN      False
# 6311       NaN    NaN               NaN     False      NaN       True
#
#       cuotaMantenimiento_limpia precio_con_mantenimiento
# 465                        0.00                 15000.00
# 836                        0.00                463840.00
# 1129                       0.00               1026270.00
# 1455                       0.00               1250000.00
# 1907                       0.00               1800000.00
# 2303                       0.00               2225000.00
# 2451                       0.00               3050000.00
# 2562                       0.00               2500000.00
# 2810                       0.00               2800000.00
# 3479                       0.00               3640018.00
# 3854                       0.00               3950000.00
# 4367                       0.00               5000000.00
# 5379                       0.00               7500000.00
# 5764                       0.00              10000000.00
# 5872                       0.00              11327723.00
# 6311                       0.00              18000000.00
#
# [16 rows x 23 columns]

# %% [markdown]
# Se decide eliminar las siguientes filas debido a que son terrenos en venta y no casas realmente y por ello tienen las recamaras y baños como nulos

# %%
df_casa.drop(index=[836,1129,1455,1907,2303,2451,3479,5872,6311], inplace=True) 
df_casa.reset_index(drop=True, inplace=True)

# %% [markdown]
# Se revisan casas que posee una construccion con mas de 800 metros cuadrados que posean baños y recamaras nulos

# %%
df_casa.query("(banos.isnull() or recamaras.isnull()) and m2CSort>800")
# Out:
#      mantenimiento  precioSecundarioFormat  \
# 615            NaN                27000.00
# 770            NaN                53600.00
# 792            NaN                56000.00
# 5075           NaN              6500000.00
# 6066           NaN             13500000.00
# 6238           NaN             15800000.00
# 6273           NaN             17000000.00
# 6331           NaN             18000000.00
# 6485           NaN             29900000.00
# 6500           NaN             49500000.00
# 6501           NaN             29800000.00
# 6518           NaN             36000000.00
# 6554           NaN            104000000.00
# 6612           NaN             38000000.00
# 6667           NaN             25000000.00
# 6674           NaN             22000000.00
#
#                                    urlCorrectaPropiedad  \
# 615   /propiedad/540301_casa-amueblada-en-renta-en-p...
# 770   /propiedad/325817_vinicola-en-renta-en-el-cort...
# 792   /propiedad/505780_casa-en-renta-en-cortijo-san...
# 5075  /propiedad/422921_venta-de-casa-para-remodelar...
# 6066  /propiedad/288890_ex2706-casa-en-venta-edifici...
# 6238  /propiedad/537524_casa-en-venta-fracc-los-amat...
# 6273  /propiedad/542098_antigua-casona-en-venta-cent...
# 6331                   /propiedad/539039_casas-en-venta
# 6485       /propiedad/511719_chimalistac-alvaro-obregon
# 6500  /propiedad/543222_casa-en-venta-san-juan-de-di...
# 6501  /propiedad/314961_venta-de-casa-comercial-zona...
# 6518  /propiedad/482033_casa-en-venta-av-de-las-indu...
# 6554  /propiedad/504724_casa-en-venta-en-esquina-san...
# 6612  /propiedad/472753_casa-en-venta-en-rincon-de-l...
# 6667  /propiedad/469253_casa-en-venta-col-residencia...
# 6674  /propiedad/451451_casas-en-venta-col-nueva-min...
#
#                                             colonia  \
# 615                         Praderas De La Hacienda
# 770                                      El Cortijo
# 792                          Cortijo De San Agustin
# 5075                              Joyas De Brisamar
# 6066                                        Moderna
# 6238                                    Ixtlahuacan
# 6273                                         Centro
# 6331                                        Morelos
# 6485           Ex-Hacienda de Guadalupe Chimalistac
# 6500                           San Lorenzo Huipulco
# 6501                                         Centro
# 6518                                     Sector Sur
# 6554                        Zona Loma Larga Oriente
# 6612  Rincón De Las Montañas (Sierra Alta 8 Sector)
# 6667                                        A I M P
# 6674                               Nuevo Minatitlan
#
#                       municipio            estado   lat     lon tipoOperacion  \
# 615                      Celaya        Guanajuato 20.57 -100.81         renta
# 770   San Francisco De Los Romo    Aguascalientes 22.02 -102.29         renta
# 792        Tlajomulco De Zúñiga           Jalisco 20.54 -103.46         renta
# 5075                   Acapulco          Guerrero 16.83  -99.85         venta
# 6066                  Monterrey        Nuevo León 25.70 -100.29         venta
# 6238                   Yautepec           Morelos 18.90  -99.06         venta
# 6273                     Puebla            Puebla 19.04  -98.20         venta
# 6331                   Saltillo          Coahuila 25.42 -100.94         venta
# 6485             Alvaro Obregón  Ciudad De México 19.35  -99.18         venta
# 6500                    Tlalpan  Ciudad De México 19.30  -99.15         venta
# 6501         San Andrés Cholula            Puebla 19.06  -98.30         venta
# 6518                   Delicias         Chihuahua 28.18 -105.45         venta
# 6554     San Pedro Garza García        Nuevo León 25.65 -100.34         venta
# 6612                  Monterrey        Nuevo León 25.56 -100.28         venta
# 6667       Poza Rica De Hidalgo          Veracruz 20.51  -97.44         venta
# 6674                 Minatitlan          Veracruz 17.98  -94.57         venta
#
#      cuotaMantenimiento  ...  m2TSort m2CSort recamaras  banos  \
# 615                 NaN  ...  2000.00  850.00       NaN    NaN
# 770                 NaN  ...  2680.00 3000.00       NaN   0.00
# 792                 NaN  ...  2200.00 1517.00       NaN    NaN
# 5075                NaN  ...   305.00 1240.00       NaN    NaN
# 6066                NaN  ...  1196.00 1540.00       NaN   3.00
# 6238                NaN  ...  2359.00 1212.69       NaN    NaN
# 6273                NaN  ...   572.45  968.65     19.00    NaN
# 6331                NaN  ...  5000.00 4486.00       NaN    NaN
# 6485                NaN  ...   519.85  924.00       NaN   3.00
# 6500                NaN  ...  1906.00 1430.00       NaN    NaN
# 6501                NaN  ...  1088.00 1018.00     11.00    NaN
# 6518                NaN  ...  7899.57 3068.00       NaN    NaN
# 6554                NaN  ...  2700.00 1500.00       NaN    NaN
# 6612                NaN  ...  1100.00 1187.00       NaN   4.00
# 6667                NaN  ...  1159.77 1850.40       NaN    NaN
# 6674                NaN  ...  3691.80 2882.25       NaN    NaN
#
#       estacionamientos  mascotas  alberca  exclusiva  \
# 615                NaN     False      NaN      False
# 770              20.00      True      NaN       True
# 792                NaN     False      NaN       True
# 5075               NaN     False      NaN      False
# 6066               NaN      True      NaN       True
# 6238             14.00     False     True      False
# 6273               NaN      True      NaN      False
# 6331               NaN     False      NaN       True
# 6485               NaN     False      NaN       True
# 6500             15.00      True     True       True
# 6501               NaN      True      NaN      False
# 6518               NaN      True     True      False
# 6554               NaN     False     True       True
# 6612               NaN      True     True      False
# 6667              4.00     False      NaN       True
# 6674               NaN     False      NaN       True
#
#       cuotaMantenimiento_limpia precio_con_mantenimiento
# 615                        0.00                 27000.00
# 770                        0.00                 53600.00
# 792                        0.00                 56000.00
# 5075                       0.00               6500000.00
# 6066                       0.00              13500000.00
# 6238                       0.00              15800000.00
# 6273                       0.00              17000000.00
# 6331                       0.00              18000000.00
# 6485                       0.00              29900000.00
# 6500                       0.00              49500000.00
# 6501                       0.00              29800000.00
# 6518                       0.00              36000000.00
# 6554                       0.00             104000000.00
# 6612                       0.00              38000000.00
# 6667                       0.00              25000000.00
# 6674                       0.00              22000000.00
#
# [16 rows x 23 columns]

# %% [markdown]
# Se eliminan registros donde venden terrenos con mas de una casa en la publicacion, construcciones con departamentos u oficinas o que derechamente no son casas lo que se vende realmente

# %%
df_casa.drop(index=[6331,6674,6273,770,6485,6066,6500,6501,6554], inplace=True) 
df_casa.reset_index(drop=True, inplace=True)

# %% [markdown]
# Se calcula la moda de recamaras y baños por cada en cada estado

# %%
# calcula la moda agrupando por estado de recamaras y baños, en caso de que haya mas de una moda se elige la primera
moda_recamaras = df_casa.groupby('estado')['recamaras'].agg(lambda x: pd.Series.mode(x)[0]) 
moda_baños = df_casa.groupby('estado')['banos'].agg(lambda x: pd.Series.mode(x)[0])

# Combinar los resultados en un solo DataFrame
modas = pd.concat([moda_recamaras.rename('moda_recamaras'), moda_baños.rename('moda_baños')], axis=1)

print(modas)
# Out:
#                      moda_recamaras  moda_baños
# estado
# Aguascalientes                 3.00        2.00
# Baja California                3.00        2.00
# Baja California Sur            3.00        3.00
# Campeche                       2.00        2.00
# Chiapas                        3.00        2.00
# Chihuahua                      3.00        2.00
# Ciudad De México               3.00        3.00
# Coahuila                       3.00        2.00
# Colima                         3.00        2.00
# Durango                        3.00        2.00
# Estado De México               3.00        2.00
# Guanajuato                     3.00        2.00
# Guerrero                       3.00        2.00
# Hidalgo                        3.00        1.00
# Jalisco                        3.00        2.00
# Michoacán                      5.00        4.00
# Morelos                        3.00        3.00
# Nayarit                        3.00        2.00
# Nuevo León                     3.00        2.00
# Oaxaca                         3.00        2.00
# Puebla                         3.00        3.00
# Querétaro                      3.00        2.00
# Quintana Roo                   3.00        2.00
# San Luis Potosí                3.00        2.00
# Sinaloa                        3.00        2.00
# Sonora                         3.00        2.00
# Tabasco                        3.00        3.00
# Tamaulipas                     3.00        2.00
# Tlaxcala                       3.00        2.00
# Veracruz                       3.00        2.00
# Yucatán                        3.00        3.00
# Zacatecas                      3.00        1.00

# %% [markdown]
# Se utiliza la tabla de modas por estado para rellenar los nulos de baños y recamaras en los registros de casas

# %%
df_casa = pd.merge(df_casa, modas, on='estado', how='left')

# columna para identifcar columnas con nulos
df_casa.loc[df_casa['recamaras'].isna(),'recamaras_na'] = 1
df_casa.loc[df_casa['banos'].isna(),'banos_na'] = 1

# se rellenan los nulos con el promedio del estado
df_casa['recamaras'] = df_casa['recamaras'].fillna(df_casa['moda_recamaras']) 
df_casa['banos'] = df_casa['banos'].fillna(df_casa['moda_baños'])

# se eliminan las columnas de moda 
df_casa=df_casa.drop(columns=['moda_recamaras', 'moda_baños'])
df_casa
# Out:
#              mantenimiento  precioSecundarioFormat  \
# 0                      NaN                11500.00
# 1                      NaN                11000.00
# 2                      NaN                 5000.00
# 3      + 850 mantenimiento                10000.00
# 4                      NaN                11500.00
# ...                    ...                     ...
# 6667                   NaN             40000000.00
# 6668                   NaN             84889429.00
# 6669                   NaN             23880000.00
# 6670                   NaN             25000000.00
# 6671                   NaN            111258711.00
#
#                                    urlCorrectaPropiedad  \
# 0     /propiedad/525486_casa-en-condominio-horizonta...
# 1     /propiedad/554808_casa-en-renta-1-planta-de-2-...
# 2     /propiedad/554850_casa-en-renta-en-rinconada-d...
# 3     /propiedad/554742_casa-en-renta-sin-amueblar-z...
# 4     /propiedad/554583_casa-disponible-para-renta-s...
# ...                                                 ...
# 6667  /propiedad/447192_santa-maria-mazatla-casa-en-...
# 6668  /propiedad/404769_404769-casa-en-venta-en-col-...
# 6669                           /propiedad/384569_384569
# 6670  /propiedad/350961_residencia-a-orilla-de-mar-a...
# 6671  /propiedad/223858_casa-en-venta-aldila-puerto-...
#
#                             colonia               municipio            estado  \
# 0                      El Contadero   Cuajimalpa De Morelos  Ciudad De México
# 1                   Villa Fontana I                 Tijuana   Baja California
# 2     San José Buenavista El Grande                 Temoaya  Estado De México
# 3                   Bello Horizonte                  Puebla            Puebla
# 4        Villa Residencial Santa Fe                 Tijuana   Baja California
# ...                             ...                     ...               ...
# 6667            Santa María Mazatla              Jilotzingo  Estado De México
# 6668                      Del Valle  San Pedro Garza García        Nuevo León
# 6669                    Gral. Bravo           General Bravo        Nuevo León
# 6670                     Buenavista                Campeche          Campeche
# 6671                    Pichilingue                Acapulco          Guerrero
#
#        lat     lon tipoOperacion cuotaMantenimiento  ...  recamaras banos  \
# 0    19.35  -99.30         renta                NaN  ...       3.00  1.00
# 1    32.51 -116.87         renta                NaN  ...       2.00  1.00
# 2    19.41  -99.58         renta                NaN  ...       3.00  2.00
# 3    19.05  -98.27         renta                850  ...       2.00  1.00
# 4    32.43 -117.03         renta                NaN  ...       2.00  1.00
# ...    ...     ...           ...                ...  ...        ...   ...
# 6667 19.51  -99.39         venta                NaN  ...       5.00  3.00
# 6668 25.66 -100.39         venta                NaN  ...       3.00  3.00
# 6669 25.79  -99.18         venta                NaN  ...       6.00  2.00
# 6670 19.83  -90.56         venta                NaN  ...       3.00  4.00
# 6671 16.81  -99.84         venta                NaN  ...       7.00  7.00
#
#      estacionamientos  mascotas  alberca  exclusiva  \
# 0                1.00     False      NaN       True
# 1                1.00     False      NaN       True
# 2                1.00     False      NaN       True
# 3                1.00      True      NaN       True
# 4                2.00     False      NaN       True
# ...               ...       ...      ...        ...
# 6667            40.00     False      NaN       True
# 6668             4.00     False      NaN       True
# 6669            10.00     False      NaN       True
# 6670             4.00      True     True      False
# 6671             3.00      True     True       True
#
#       cuotaMantenimiento_limpia  precio_con_mantenimiento  recamaras_na  \
# 0                          0.00                  11500.00           NaN
# 1                          0.00                  11000.00           NaN
# 2                          0.00                   5000.00           NaN
# 3                        850.00                  10850.00           NaN
# 4                          0.00                  11500.00           NaN
# ...                         ...                       ...           ...
# 6667                       0.00               40000000.00           NaN
# 6668                       0.00               84889429.00           NaN
# 6669                       0.00               23880000.00           NaN
# 6670                       0.00               25000000.00           NaN
# 6671                       0.00              111258711.00           NaN
#
#      banos_na
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 6667      NaN
# 6668      NaN
# 6669      NaN
# 6670      NaN
# 6671      NaN
#
# [6672 rows x 25 columns]

# %%
df_casa[df_casa['recamaras_na'].notna()]
# Out:
#                   mantenimiento  precioSecundarioFormat  \
# 13                          NaN                 9500.00
# 93     - Mantenimiento incluído                 5500.00
# 94     - Mantenimiento incluído                 5500.00
# 139                         NaN                10000.00
# 142                         NaN                 8000.00
# ...                         ...                     ...
# 6483                        NaN             65550000.00
# 6511                        NaN             36000000.00
# 6604                        NaN             38000000.00
# 6610                        NaN             34000000.00
# 6659                        NaN             25000000.00
#
#                                    urlCorrectaPropiedad  \
# 13    /propiedad/554072_se-renta-casa-priv-azul-mina...
# 93    /propiedad/548361_casa-en-renta-en-real-navarr...
# 94    /propiedad/548364_renta-de-casa-en-fraccionami...
# 139          /propiedad/539599_casa-habitacion-en-renta
# 142   /propiedad/501718_casa-de-renta-vacacional-lom...
# ...                                                 ...
# 6483  /propiedad/545268_residencia-en-venta-en-reser...
# 6511  /propiedad/482033_casa-en-venta-av-de-las-indu...
# 6604  /propiedad/472753_casa-en-venta-en-rincon-de-l...
# 6610         /propiedad/464478_san-angel-alvaro-obregon
# 6659  /propiedad/469253_casa-en-venta-col-residencia...
#
#                                             colonia  \
# 13                                        Mina Azul
# 93                                     Real Navarra
# 94                                     Real Navarra
# 139                                       San Mateo
# 142                             Lomas De Cuernavaca
# ...                                             ...
# 6483                                     Valle Real
# 6511                                     Sector Sur
# 6604  Rincón De Las Montañas (Sierra Alta 8 Sector)
# 6610                                      San Angel
# 6659                                        A I M P
#
#                       municipio            estado   lat     lon tipoOperacion  \
# 13                    Guadalupe         Zacatecas 22.73 -102.50         renta
# 93                     Zempoala           Hidalgo 20.00  -98.79         renta
# 94                     Zempoala           Hidalgo 20.00  -98.79         renta
# 139   Chilpancingo De Los Bravo          Guerrero 17.56  -99.50         renta
# 142                     Temixco           Morelos 18.87  -99.22         renta
# ...                         ...               ...   ...     ...           ...
# 6483                    Zapopan           Jalisco 20.72 -103.45         venta
# 6511                   Delicias         Chihuahua 28.18 -105.45         venta
# 6604                  Monterrey        Nuevo León 25.56 -100.28         venta
# 6610             Alvaro Obregón  Ciudad De México 19.34  -99.20         venta
# 6659       Poza Rica De Hidalgo          Veracruz 20.51  -97.44         venta
#
#      cuotaMantenimiento  ...  recamaras banos estacionamientos  mascotas  \
# 13                  NaN  ...       3.00  1.00              NaN     False
# 93                  300  ...       3.00  1.00              NaN     False
# 94                  300  ...       3.00  1.00              NaN     False
# 139                 NaN  ...       3.00  2.00              NaN     False
# 142                 NaN  ...       3.00  3.00              NaN      True
# ...                 ...  ...        ...   ...              ...       ...
# 6483                NaN  ...       3.00  2.00              NaN     False
# 6511                NaN  ...       3.00  2.00              NaN      True
# 6604                NaN  ...       3.00  4.00              NaN      True
# 6610                NaN  ...       3.00  3.00              NaN     False
# 6659                NaN  ...       3.00  2.00             4.00     False
#
#       alberca  exclusiva  cuotaMantenimiento_limpia  precio_con_mantenimiento  \
# 13        NaN       True                       0.00                   9500.00
# 93        NaN       True                     300.00                   5800.00
# 94        NaN       True                     300.00                   5800.00
# 139       NaN       True                       0.00                  10000.00
# 142      True      False                       0.00                   8000.00
# ...       ...        ...                        ...                       ...
# 6483      NaN       True                       0.00               65550000.00
# 6511     True      False                       0.00               36000000.00
# 6604     True      False                       0.00               38000000.00
# 6610      NaN       True                       0.00               34000000.00
# 6659      NaN       True                       0.00               25000000.00
#
#       recamaras_na banos_na
# 13            1.00      NaN
# 93            1.00     1.00
# 94            1.00     1.00
# 139           1.00     1.00
# 142           1.00     1.00
# ...            ...      ...
# 6483          1.00     1.00
# 6511          1.00     1.00
# 6604          1.00      NaN
# 6610          1.00     1.00
# 6659          1.00     1.00
#
# [297 rows x 25 columns]

# %% [markdown]
# Se usa el rango intercuartílico para el tratamiento de outliers

# %%
Q1_casa = df_casa['precioSecundarioFormat'].quantile(0.25)
Q3_casa = df_casa['precioSecundarioFormat'].quantile(0.75)
IQR_casa = Q3_casa - Q1_casa

lower_limit_casa = Q1_casa - 1.5 * IQR_casa
upper_limit_casa = Q3_casa + 1.5 * IQR_casa

outliers_casa = df_casa[(df_casa['precioSecundarioFormat'] < lower_limit_casa) | (df_casa['precioSecundarioFormat'] > upper_limit_casa)]
largo_outliers_casa = len(outliers_casa)
print(f'el lower limit de casa es {lower_limit_casa}')
print(f'el upper limit de casa es {upper_limit_casa}')
print(f'La cantidadd de outliers para el df de casas es {largo_outliers_casa}')
# Out:
# el lower limit de casa es -5375000.0
# el upper limit de casa es 13625000.0
# La cantidadd de outliers para el df de casas es 600

# %% [markdown]
# Se imputan los outliers con el valor del upper limit, no se usa el lower limit en la siguiente condición ya que es un valor negativo

# %%
df_casa['precio_imputado'] = np.where(
    (df_casa['precioSecundarioFormat'] > upper_limit_casa),
    upper_limit_casa, 
    df_casa['precioSecundarioFormat']  
)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot(df_casa['precioSecundarioFormat'])
plt.title('Con Outliers')

plt.subplot(1, 2, 2)
plt.boxplot(df_casa['precio_imputado'])
plt.title('Outliers imputados')

plt.show()

# %%
df_casa['tipoPropiedadTrans'].value_counts()
# Out:
# tipoPropiedadTrans
# casa    6672
# Name: count, dtype: int64

# %% [markdown]
# Se repiten los pasos para el df de departamenos

# %%
df_dpto.groupby(['tipoOperacion'])['precioSecundarioFormat'].describe()
# Out:
#                 count       mean         std     min        25%        50%  \
# tipoOperacion
# renta          783.00   20845.78    17880.47 1200.00   10642.00   16500.00
# venta         4223.00 5785048.13 13555213.11 2200.00 2700000.00 4037500.00
#
#                      75%          max
# tipoOperacion
# renta           24500.00    174144.00
# venta         6385283.00 781583194.00

# %% [markdown]
# Se revisan los departamentos con precios muy bajos

# %%
df_dpto[(df_dpto['precioSecundarioFormat']<3000)]
# Out:
#                  mantenimiento  precioSecundarioFormat  \
# 24    - Mantenimiento incluído                 2950.00
# 133   - Mantenimiento incluído                 2300.00
# 204                        NaN                 1500.00
# 205                        NaN                 1200.00
# 798                        NaN                 2200.00
#
#                                   urlCorrectaPropiedad  \
# 24   /propiedad/532917_renta-de-departamento-en-jar...
# 133  /propiedad/544029_departamento-semi-amueblado-...
# 204  /propiedad/521439_departamento-amueblado-marin...
# 205  /propiedad/434162_cuartos-en-renta-col-ampliac...
# 798  /propiedad/474057_departamento-en-renta-otilio...
#
#                      colonia                  municipio            estado  \
# 24   San Bartolo Cuautlalpan                   Zumpango  Estado De México
# 133      Villas De La Laguna                   Zumpango  Estado De México
# 204           Barra Diamante                   Acapulco          Guerrero
# 205               La Florida  Chilpancingo De Los Bravo          Guerrero
# 798           Otilio Montaño                 Cuernavaca           Morelos
#
#       lat    lon tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort  \
# 24  19.80 -99.03         renta                250  ...    56.30   52.00
# 133 19.83 -99.09         renta                250  ...    70.00   70.00
# 204 16.77 -99.77         renta                NaN  ...    84.00   84.00
# 205 17.54 -99.52         renta                NaN  ...   120.00   50.00
# 798 18.92 -99.17         venta                NaN  ...    35.00   35.00
#
#     recamaras  banos  estacionamientos  mascotas  alberca  exclusiva  \
# 24       2.00   1.00              1.00     False      NaN       True
# 133      2.00   1.00               NaN     False      NaN       True
# 204      2.00   2.00              2.00      True     True       True
# 205      1.00   1.00               NaN     False      NaN       True
# 798      1.00   1.00              0.00     False      NaN       True
#
#      cuotaMantenimiento_limpia precio_con_mantenimiento
# 24                      250.00                  3200.00
# 133                     250.00                  2550.00
# 204                       0.00                  1500.00
# 205                       0.00                  1200.00
# 798                       0.00                  2200.00
#
# [5 rows x 23 columns]

# %% [markdown]
# Además se revisan departamentos en venta por debajo de los 400.000 MXN

# %%
df_dpto[((df_dpto['precioSecundarioFormat']<400000) & (df_dpto['tipoOperacion']=='venta'))]
# Out:
#               mantenimiento  precioSecundarioFormat  \
# 783                     NaN                25000.00
# 784                     NaN                50000.00
# 785                     NaN                16500.00
# 786   + 3,500 mantenimiento                14000.00
# 787                     NaN               380000.00
# 788                     NaN                18000.00
# 790                     NaN               350000.00
# 794                     NaN               320000.00
# 795                     NaN               350000.00
# 797                     NaN                30000.00
# 798                     NaN                 2200.00
# 799                     NaN               350000.00
# 800                     NaN               350000.00
# 801                     NaN               360000.00
# 802                     NaN               370000.00
# 803                     NaN               360000.00
#
#                                   urlCorrectaPropiedad  \
# 783  /propiedad/554680_en-renta-hermoso-departament...
# 784  /propiedad/533935_departamos-en-preventa-en-da...
# 785  /propiedad/552060_estudio-en-renta-the-shore-a...
# 786  /propiedad/550338_departamento-en-renta-en-vel...
# 787  /propiedad/548866_departamento-en-venta-en-fra...
# 788  /propiedad/545378_en-renta-departamento-sin-mu...
# 790  /propiedad/538719_se-vende-departamento-en-vil...
# 794  /propiedad/489346_departamento-en-venta-en-los...
# 795     /propiedad/493141_departamento-cerca-de-toluca
# 797  /propiedad/481198_haab-departamento-2-rec-a-pa...
# 798  /propiedad/474057_departamento-en-renta-otilio...
# 799  /propiedad/480537_departamento-economico-en-venta
# 800  /propiedad/462080_departamento-economico-en-ve...
# 801  /propiedad/440792_departamento-economico-en-ve...
# 802  /propiedad/440781_departamento-economico-en-ve...
# 803  /propiedad/426202_departamento-en-venta-fracc-...
#
#                      colonia                   municipio            estado  \
# 783  Playa Del Carmen Centro  Solidaridad / Riviera Maya      Quintana Roo
# 784     Vallarta Universidad                     Zapopan           Jalisco
# 785  Playa Del Carmen Centro  Solidaridad / Riviera Maya      Quintana Roo
# 786                    Tulum                       Tulum      Quintana Roo
# 787     Paseos De La Pradera          Atotonilco De Tula           Hidalgo
# 788  Playa Del Carmen Centro  Solidaridad / Riviera Maya      Quintana Roo
# 790       Lomas De Barrillas               Coatzacoalcos          Veracruz
# 794               Los Mangos                    Altamira        Tamaulipas
# 795          Colinas Del Sol          Almoloya De Juárez  Estado De México
# 797  Ciudad Playa Del Carmen  Solidaridad / Riviera Maya      Quintana Roo
# 798           Otilio Montaño                  Cuernavaca           Morelos
# 799          Colinas Del Sol          Almoloya De Juárez  Estado De México
# 800          Colinas Del Sol          Almoloya De Juárez  Estado De México
# 801          Colinas Del Sol          Almoloya De Juárez  Estado De México
# 802          Colinas Del Sol          Almoloya De Juárez  Estado De México
# 803       Lomas De Barrillas               Coatzacoalcos          Veracruz
#
#       lat     lon tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort  \
# 783 20.65  -87.10         venta                NaN  ...   103.00  103.00
# 784 20.69 -103.43         venta                NaN  ...   177.99   63.56
# 785 20.64  -87.06         venta                NaN  ...    28.00   28.00
# 786 20.20  -87.47         venta               3500  ...  1000.00   53.53
# 787 19.90  -99.22         venta                NaN  ...    53.00   47.00
# 788 20.61  -87.12         venta                NaN  ...    95.00   95.00
# 790 18.15  -94.54         venta                NaN  ...    44.03   44.03
# 794 22.42  -97.93         venta                NaN  ...    34.74   34.74
# 795 19.37  -99.76         venta                NaN  ...    38.00   38.00
# 797 20.64  -87.06         venta                NaN  ...   120.00  118.00
# 798 18.92  -99.17         venta                NaN  ...    35.00   35.00
# 799 19.37  -99.74         venta                NaN  ...     0.00   37.00
# 800 19.37  -99.74         venta                NaN  ...     0.00   35.00
# 801 19.37  -99.74         venta                NaN  ...    45.00   38.00
# 802 19.37  -99.74         venta                NaN  ...    40.00   38.00
# 803 18.15  -94.55         venta                NaN  ...    45.79   45.79
#
#     recamaras  banos  estacionamientos  mascotas  alberca  exclusiva  \
# 783      3.00   2.00              1.00     False     True      False
# 784       NaN    NaN               NaN     False      NaN       True
# 785       NaN   1.00               NaN     False     True      False
# 786      1.00   1.00              1.00      True     True       True
# 787      2.00   1.00              1.00     False      NaN       True
# 788      3.00   2.00              1.00     False     True      False
# 790      2.00   1.00               NaN     False      NaN       True
# 794      2.00   1.00               NaN     False      NaN       True
# 795      1.00   1.00              1.00     False      NaN       True
# 797      2.00   1.00              1.00     False     True      False
# 798      1.00   1.00              0.00     False      NaN       True
# 799      2.00   1.00               NaN     False      NaN       True
# 800      2.00   1.00              1.00     False      NaN       True
# 801      2.00   1.00              1.00     False      NaN       True
# 802      2.00   1.00              1.00     False      NaN       True
# 803      2.00   1.00              1.00      True      NaN       True
#
#      cuotaMantenimiento_limpia precio_con_mantenimiento
# 783                       0.00                 25000.00
# 784                       0.00                 50000.00
# 785                       0.00                 16500.00
# 786                    3500.00                 17500.00
# 787                       0.00                380000.00
# 788                       0.00                 18000.00
# 790                       0.00                350000.00
# 794                       0.00                320000.00
# 795                       0.00                350000.00
# 797                       0.00                 30000.00
# 798                       0.00                  2200.00
# 799                       0.00                350000.00
# 800                       0.00                350000.00
# 801                       0.00                360000.00
# 802                       0.00                370000.00
# 803                       0.00                360000.00
#
# [16 rows x 23 columns]

# %%
total_dpto = len(df_dpto)
nulos_dpto = df_dpto['precioSecundarioFormat'].isna().sum()
prtje_nulos_dpto = (nulos_dpto/total_dpto)*100

print(f'El porcentaje de nulos es {prtje_nulos_dpto:.2f}%')
# Out:
# El porcentaje de nulos es 0.99%

# %% [markdown]
# Se eliminan los nulos

# %%
df_dpto.dropna(subset=['precioSecundarioFormat'], inplace=True)

# %% [markdown]
# Se eliminan los 2 departamenos con menor valor ya que el arriendo es por noche y el otro es por cuarto, además, se eliminan 2 departamenos debido a que uno era precio de venta por metro cuadrado y el otro anuncio fue bajado por lo que no hay info del valor de venta bajo que tiene. Tambien se modifican 5 departamenos que estaban en la categoria de venta pero el anuncio es de renta realmente.

# %%
df_dpto.drop(index=[204, 205, 784, 797], inplace=True) 
df_dpto.loc[[783,785,786,788,798], 'tipoOperacion'] = 'renta'
df_dpto.reset_index(drop=True, inplace=True)

# %% [markdown]
# Se revisan departamentos con baños o recamaras nulos bajo los 20 metros cuadrados de construcción

# %%
df_dpto.query("(banos.isnull() or recamaras.isnull()) and m2CSort<20")
# Out:
#      mantenimiento  precioSecundarioFormat  \
# 100            NaN                 4000.00
# 891            NaN               620000.00
# 1152           NaN              1920000.00
# 1351           NaN              1578000.00
# 1356           NaN              1700000.00
# 2754           NaN              3861297.00
# 3748           NaN              5500000.00
#
#                                    urlCorrectaPropiedad  \
# 100   /propiedad/548899_habitacion-independiente-a-l...
# 891   /propiedad/539487_venta-de-departamentos-desde...
# 1152  /propiedad/411181_estudios-minimalistas-en-ven...
# 1351  /propiedad/471981_departamento-planta-baja-en-...
# 1356            /propiedad/426505_departamento-en-venta
# 2754      /propiedad/522886_departamentos-en-venta-voel
# 3748  /propiedad/379837_se-vende-11-departamentos-ex...
#
#                       colonia                   municipio            estado  \
# 100                Roma Norte                  Cuauhtémoc  Ciudad De México
# 891     Jardines De Champayán                     Tampico        Tamaulipas
# 1152  Ciudad Playa Del Carmen  Solidaridad / Riviera Maya      Quintana Roo
# 1351                  Morelos                    Jiutepec           Morelos
# 1356     Coatzacoalcos Centro               Coatzacoalcos          Veracruz
# 2754    Nazario S Ortiz Garza                    Saltillo          Coahuila
# 3748               Los Alamos                     Nogales            Sonora
#
#        lat     lon tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort  \
# 100  19.42  -99.16         renta                NaN  ...    10.00   10.00
# 891  22.32  -97.90         venta                NaN  ...     0.00    0.00
# 1152 20.65  -87.06         venta                NaN  ...    37.88    1.96
# 1351 18.93  -99.18         venta                NaN  ...     0.00    0.00
# 1356 18.15  -94.42         venta                NaN  ...   300.00    0.00
# 2754 25.45 -100.97         venta                NaN  ...    60.00    1.00
# 3748 31.29 -110.92         venta                NaN  ...   312.50    0.00
#
#      recamaras  banos  estacionamientos  mascotas  alberca  exclusiva  \
# 100        NaN   1.00               NaN     False      NaN       True
# 891        NaN    NaN               NaN     False      NaN      False
# 1152       NaN   1.00               NaN     False     True       True
# 1351       NaN    NaN               NaN     False      NaN      False
# 1356       NaN    NaN               NaN     False      NaN       True
# 2754       NaN    NaN               NaN     False      NaN       True
# 3748       NaN    NaN               NaN     False      NaN       True
#
#       cuotaMantenimiento_limpia precio_con_mantenimiento
# 100                        0.00                  4000.00
# 891                        0.00                620000.00
# 1152                       0.00               1920000.00
# 1351                       0.00               1578000.00
# 1356                       0.00               1700000.00
# 2754                       0.00               3861297.00
# 3748                       0.00               5500000.00
#
# [7 rows x 23 columns]

# %% [markdown]
# Además, se revisan departamentos sobre los 250 metros cuadrados de construcción que posean baños o recamaras como nulo

# %%
df_dpto.query("(banos.isnull() or recamaras.isnull()) and m2CSort>250")
# Out:
#      mantenimiento  precioSecundarioFormat  \
# 749            NaN                85000.00
# 1600           NaN              2120000.00
# 1691           NaN              2147777.00
# 2469           NaN              2950000.00
# 2540           NaN              3850519.00
# 3740           NaN              5708056.00
# 3794           NaN              5708056.00
# 3795           NaN              5611309.00
# 3809           NaN              5550000.00
# 4735           NaN             13590000.00
# 4837           NaN             16800000.00
# 4845           NaN             17500000.00
# 4858           NaN             18200000.00
# 5001           NaN             82000000.00
#
#                                    urlCorrectaPropiedad  \
# 749   /propiedad/516596_departamento-loft-en-lomas-d...
# 1600  /propiedad/499703_departamentos-en-venta-en-co...
# 1691  /propiedad/413608_departamentos-en-venta-en-pl...
# 2469  /propiedad/353805_edificio-en-venta-calle-tran...
# 2540  /propiedad/420143_lotes-y-villas-en-venta-en-p...
# 3740  /propiedad/535836_villa-la-estancia-3303-1-8-c...
# 3794           /propiedad/420556_departamentos-en-venta
# 3795                /propiedad/420560_edificio-en-venta
# 3809  /propiedad/499011_departamentos-en-venta-3-cir...
# 4735  /propiedad/532741_departamento-en-venta-en-cos...
# 4837  /propiedad/484403_ampliacion-napoles-benito-ju...
# 4845  /propiedad/532742_departamento-en-venta-en-cos...
# 4858  /propiedad/432019_departmentos-en-venta-centau...
# 5001            /propiedad/370536_napoles-benito-juarez
#
#                       colonia                   municipio  \
# 749          Lomas De Bezares              Miguel Hidalgo
# 1600      Belisario Domínguez                     Nogales
# 1691  Playa Del Carmen Centro  Solidaridad / Riviera Maya
# 2469            Benito Juárez                  Agua Dulce
# 2540  Ciudad Playa Del Carmen  Solidaridad / Riviera Maya
# 3740                El Medano                   Los Cabos
# 3794             Tulum Centro                       Tulum
# 3795             Tulum Centro                       Tulum
# 3809              Tecnológica                   Fresnillo
# 4735           Telchac Puerto              Telchac Puerto
# 4837              Nápoles Amp               Benito Juárez
# 4845           Telchac Puerto              Telchac Puerto
# 4858              Tecnológico                  Cuauhtémoc
# 5001                  Nápoles               Benito Juárez
#
#                    estado   lat     lon tipoOperacion cuotaMantenimiento  ...  \
# 749      Ciudad De México 19.39  -99.24         renta                NaN  ...
# 1600               Sonora 31.30 -110.93         venta                NaN  ...
# 1691         Quintana Roo 20.64  -87.07         venta                NaN  ...
# 2469             Veracruz 18.14  -94.15         venta                NaN  ...
# 2540         Quintana Roo 20.76  -86.96         venta                NaN  ...
# 3740  Baja California Sur 22.89 -109.90         venta                NaN  ...
# 3794         Quintana Roo 20.20  -87.46         venta                NaN  ...
# 3795         Quintana Roo 20.20  -87.47         venta                NaN  ...
# 3809            Zacatecas 23.19 -102.88         venta                NaN  ...
# 4735              Yucatán 21.34  -89.26         venta                NaN  ...
# 4837     Ciudad De México 19.39  -99.18         venta                NaN  ...
# 4845              Yucatán 21.34  -89.26         venta                NaN  ...
# 4858            Chihuahua 28.42 -106.91         venta                NaN  ...
# 5001     Ciudad De México 19.39  -99.18         venta                NaN  ...
#
#       m2TSort  m2CSort recamaras  banos  estacionamientos  mascotas  alberca  \
# 749    320.00   320.00       NaN    NaN               NaN     False     True
# 1600   200.00   286.00       NaN    NaN               NaN     False      NaN
# 1691  2320.00 11400.00       NaN    NaN               NaN     False     True
# 2469   509.00   425.00       NaN   0.00              4.00      True      NaN
# 2540   400.00   400.00       NaN    NaN               NaN      True     True
# 3740   256.00   256.00       NaN    NaN               NaN     False      NaN
# 3794  1288.83  3347.00       NaN    NaN               NaN     False      NaN
# 3795   491.00  1500.00       NaN    NaN               NaN     False      NaN
# 3809   280.00   433.00       NaN    NaN               NaN     False      NaN
# 4735   339.50   290.00       NaN    NaN               NaN     False      NaN
# 4837   352.00   352.00      1.00    NaN               NaN     False      NaN
# 4845   479.50   393.00       NaN    NaN               NaN     False      NaN
# 4858 10000.00  1200.00       NaN    NaN               NaN     False      NaN
# 5001   336.79  2269.00       NaN    NaN               NaN     False      NaN
#
#       exclusiva  cuotaMantenimiento_limpia precio_con_mantenimiento
# 749       False                       0.00                 85000.00
# 1600      False                       0.00               2120000.00
# 1691      False                       0.00               2147777.00
# 2469       True                       0.00               2950000.00
# 2540       True                       0.00               3850519.00
# 3740       True                       0.00               5708056.00
# 3794       True                       0.00               5708056.00
# 3795       True                       0.00               5611309.00
# 3809       True                       0.00               5550000.00
# 4735      False                       0.00              13590000.00
# 4837       True                       0.00              16800000.00
# 4845      False                       0.00              17500000.00
# 4858       True                       0.00              18200000.00
# 5001       True                       0.00              82000000.00
#
# [14 rows x 23 columns]

# %% [markdown]
# Se eliminan registros que ofrecen edificios completos con departamentos o no cumplen el parametro para considerarse departamento

# %%
df_dpto.drop(index=[1691,2469,2540,3794,4858,5001,891,3748,100], inplace=True) 
df_dpto.reset_index(drop=True, inplace=True)

# %% [markdown]
# Se calcula la moda de recamaras y baños por cada en cada estado

# %%
# calcula la moda agrupando por estado de recamaras y baños, en caso de que haya mas de una moda se elige la primera
moda_recamaras = df_dpto.groupby('estado')['recamaras'].agg(lambda x: pd.Series.mode(x)[0]) 
moda_baños = df_dpto.groupby('estado')['banos'].agg(lambda x: pd.Series.mode(x)[0])

# Combinar los resultados en un solo DataFrame
modas = pd.concat([moda_recamaras.rename('moda_recamaras'), moda_baños.rename('moda_baños')], axis=1)

print(modas)
# Out:
#                      moda_recamaras  moda_baños
# estado
# Aguascalientes                 2.00        2.00
# Baja California                2.00        2.00
# Baja California Sur            2.00        2.00
# Campeche                       4.00        4.00
# Chiapas                        1.00        1.00
# Chihuahua                      2.00        1.00
# Ciudad De México               2.00        2.00
# Coahuila                       2.00        2.00
# Colima                         2.00        2.00
# Durango                        2.00        1.00
# Estado De México               2.00        2.00
# Guanajuato                     1.00        2.00
# Guerrero                       3.00        2.00
# Hidalgo                        2.00        1.00
# Jalisco                        2.00        2.00
# Morelos                        2.00        2.00
# Nayarit                        2.00        2.00
# Nuevo León                     2.00        2.00
# Oaxaca                         1.00        1.00
# Puebla                         2.00        2.00
# Querétaro                      2.00        2.00
# Quintana Roo                   2.00        1.00
# San Luis Potosí                2.00        2.00
# Sinaloa                        2.00        2.00
# Sonora                         2.00        2.00
# Tabasco                        3.00        2.00
# Tamaulipas                     2.00        1.00
# Tlaxcala                       1.00        1.00
# Veracruz                       2.00        1.00
# Yucatán                        2.00        2.00
# Zacatecas                      2.00        1.00

# %%
df_dpto = pd.merge(df_dpto, modas, on='estado', how='left')

# se rellenan los nulos con el promedio del estado
df_dpto['recamaras'] = df_dpto['recamaras'].fillna(df_dpto['moda_recamaras']) 
df_dpto['banos'] = df_dpto['banos'].fillna(df_dpto['moda_baños'])

# se eliminan las columnas de moda 
df_dpto=df_dpto.drop(columns=['moda_recamaras', 'moda_baños'])
df_dpto
# Out:
#              mantenimiento  precioSecundarioFormat  \
# 0                      NaN                10000.00
# 1      + 700 mantenimiento                10000.00
# 2                      NaN                10500.00
# 3                      NaN                10000.00
# 4                      NaN                10000.00
# ...                    ...                     ...
# 4988                   NaN             30958946.00
# 4989                   NaN             29900000.00
# 4990                   NaN             24186676.00
# 4991                   NaN             24061037.00
# 4992                   NaN             27089077.00
#
#                                    urlCorrectaPropiedad           colonia  \
# 0     /propiedad/550419_departamento-en-renta-en-col...         El Jagüey
# 1     /propiedad/554694_se-renta-departamento-coloni...   Viaducto Piedad
# 2     /propiedad/512706_oportunidad-de-renta-departa...            Centro
# 3     /propiedad/554668_departamento-en-renta-en-caf...         Cafetales
# 4     /propiedad/554669_departamento-en-renta-en-caf...         Cafetales
# ...                                                 ...               ...
# 4988  /propiedad/498592_garden-house-en-playa-del-ca...  Playacar Fase II
# 4989  /propiedad/496940_departamento-en-venta-en-pue...     Puerto Cancún
# 4990  /propiedad/495600_departamento-en-venta-en-av-...     Puerto Cancún
# 4991  /propiedad/494590_departamento-en-venta-blume-...     Puerto Cancún
# 4992  /propiedad/478838_condominio-de-7-departamento...      La Audiencia
#
#                        municipio            estado   lat     lon  \
# 0                   Azcapotzalco  Ciudad De México 19.49  -99.17
# 1                      Iztacalco  Ciudad De México 19.40  -99.13
# 2                 Aguascalientes    Aguascalientes 21.89 -102.30
# 3                      Chihuahua         Chihuahua 28.72 -106.14
# 4                      Chihuahua         Chihuahua 28.72 -106.14
# ...                          ...               ...   ...     ...
# 4988  Solidaridad / Riviera Maya      Quintana Roo 20.62  -87.08
# 4989        Cancún/Benito Juárez      Quintana Roo 21.16  -86.80
# 4990        Cancún/Benito Juárez      Quintana Roo 21.16  -86.81
# 4991        Cancún/Benito Juárez      Quintana Roo 21.18  -86.81
# 4992                  Manzanillo            Colima 19.11 -104.35
#
#      tipoOperacion cuotaMantenimiento  ...  m2TSort m2CSort recamaras  banos  \
# 0            renta                NaN  ...    50.00   50.00      2.00   1.00
# 1            renta                700  ...     0.00   56.92      1.00   1.00
# 2            renta                NaN  ...   170.00  170.00      3.00   2.00
# 3            renta                NaN  ...   135.00   72.00      2.00   1.00
# 4            renta                NaN  ...   135.00   64.00      2.00   1.00
# ...            ...                ...  ...      ...     ...       ...    ...
# 4988         venta                NaN  ...   244.00  244.00      4.00   3.00
# 4989         venta                NaN  ...   480.00  480.00      4.00   5.00
# 4990         venta                NaN  ...   256.00  256.00      3.00   4.00
# 4991         venta                 m2  ...   256.61  256.61      3.00   4.00
# 4992         venta                NaN  ...  1177.05 1200.00     12.00  12.00
#
#       estacionamientos  mascotas  alberca  exclusiva  \
# 0                 1.00     False      NaN       True
# 1                  NaN     False      NaN       True
# 2                 2.00     False      NaN      False
# 3                 1.00     False      NaN      False
# 4                 1.00     False      NaN      False
# ...                ...       ...      ...        ...
# 4988              2.00      True     True      False
# 4989              1.00      True     True       True
# 4990              2.00      True     True      False
# 4991              2.00      True     True       True
# 4992              8.00      True     True       True
#
#       cuotaMantenimiento_limpia precio_con_mantenimiento
# 0                          0.00                 10000.00
# 1                        700.00                 10700.00
# 2                          0.00                 10500.00
# 3                          0.00                 10000.00
# 4                          0.00                 10000.00
# ...                         ...                      ...
# 4988                       0.00              30958946.00
# 4989                       0.00              29900000.00
# 4990                       0.00              24186676.00
# 4991                       2.00              24061039.00
# 4992                       0.00              27089077.00
#
# [4993 rows x 23 columns]

# %% [markdown]
# Rango intercuartílico

# %%
Q1_dpto = df_dpto['precioSecundarioFormat'].quantile(0.25)
Q3_dpto = df_dpto['precioSecundarioFormat'].quantile(0.75)
IQR_dpto = Q3_dpto - Q1_dpto

lower_limit_dpto = Q1_dpto - 1.5 * IQR_dpto
upper_limit_dpto = Q3_dpto + 1.5 * IQR_dpto

outliers_dpto = df_dpto[(df_dpto['precioSecundarioFormat'] < lower_limit_dpto) | (df_dpto['precioSecundarioFormat'] > upper_limit_dpto)]
largo_outliers_dpto = len(outliers_dpto)
print(f'el lower limit de departamento es {lower_limit_dpto}')
print(f'el upper limit de departamento es {upper_limit_dpto}')
print(f'La cantidad de outliers para el df de departamentos es {largo_outliers_dpto}')
# Out:
# el lower limit de departamento es -4185000.0
# el upper limit de departamento es 11775000.0
# La cantidad de outliers para el df de departamentos es 342

# %% [markdown]
# Se imputan los outliers con el valor del upper limit, no se usa el lower limit en la siguiente condición ya que es un valor negativo

# %%
df_dpto['precio_imputado'] = np.where(
    (df_dpto['precioSecundarioFormat'] > upper_limit_dpto),
    upper_limit_dpto,  # Valor de imputación
    df_dpto['precioSecundarioFormat']  # Mantener el valor original si no es un outlier
)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.boxplot(df_dpto['precioSecundarioFormat'])
plt.title('Con Outliers')

plt.subplot(1, 2, 2)
plt.boxplot(df_dpto['precio_imputado'])
plt.title('Outliers imputados')

plt.show()

# %%
df_dpto['tipoPropiedadTrans'].value_counts()
# Out:
# tipoPropiedadTrans
# departamento    4993
# Name: count, dtype: int64
